# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import math

# %% [markdown]
# # The code is too messy to be submitted, I'll clean the code if I have time

# %% [markdown]
# # Define the predictor-corrector algorithm for this program (m=0)

# %%
def PCS(beta,S,I,v,t):  #PC method for Susceptibile 
    Spre=S-(beta*S*I)*t #predictor
    Ipre=I+(beta*S*I-v*I)*t #predictor
    Scor=S-(beta*S*I+beta*Spre*Ipre)*t/2  #corrector
    return Scor

def PCI(beta,S,I,v,t):  #PC method for infected
    Spre=S-(beta*S*I)*t #predictor
    Ipre=I+(beta*S*I-v*I)*t  #predictor
    Icor=I+(beta*S*I-v*I+beta*Spre*Ipre-v*Ipre)*t/2  #corrector
    return Icor

def PCR(S,I,R,v,t): #PC method for recovered
    Rpre=R+(v*I)*t  #predictor
    Ipre=I+(beta*S*I-v*I)*t  #predictor
    Rcor=R+(v*I+v*Ipre)*t/2  #corrector
    return Rcor

# %% [markdown]
# # Set the parameter and initial condition

# %% [markdown]
# You can simply input the inital condition and parameters or you can set the parameters manully

# %%
print("Please input beta:")
beta=eval(input())
print("Please input recovery rate v")
v=eval(input())
print("Please input birth and death rate m")
m=eval(input())
print("Now set the initial condition")
print("Please input initial S")
S=eval(input())
print("Please input initial I")
I=eval(input())
print("Please inpur initial R")
R=eval(input())
print("Set deltaT")
deltaT=eval(input())
# Out:
# Please input beta:
# Traceback (most recent call last):
#
#   File "D:\Anaconda\lib\site-packages\IPython\core\interactiveshell.py", line 3325, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-4-0397a99d1fee>", line 2, in <module>
#     beta=eval(input())
#
#   File "<string>", line unknown
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# Define the function that calculate the corresponding S,I,R values

# %% [markdown]
# For question b, the inital condiciton and parameters is beta=0.7,v=0.2, S[0]=0.9999, I[0]=0.0001, R[0]=0, and m=0, we use the ΔT=1, which is sufficiently accurate for simulation, we carried out simulation till t=100

# %%
beta=0.7
v=0.2
S=0.9999
I=0.0001
R=0
deltaT=1
days=400
T=np.linspace(1,100,100)
susc=np.zeros(100)
infe=np.zeros(100)
reco=np.zeros(100)
susc[0]=S
infe[0]=I
reco[0]=R
for i in range(99):
    susc[i+1]=PCS(beta,susc[i],infe[i],v,deltaT)
    infe[i+1]=PCI(beta,susc[i],infe[i],v,deltaT)
    reco[i+1]=PCR(susc[i],infe[i],reco[i],v,deltaT)

plt.figure(figsize=(12,12))
plt.scatter(T,susc,color="Red",linewidth="3",label="Susceptible")
plt.scatter(T,infe,color="Yellow",linewidth="3",label="Infected")
plt.scatter(T,reco,color="blue",linewidth="3",label="Recovered")
plt.title("DeltaT=1, beta=0.7",fontsize=20)
plt.xlabel("Time(Days)",fontsize=16)
plt.ylabel("Percentage of People",fontsize=16)
plt.legend(fontsize=16)

# %% [markdown]
# For question 3, we can first fit the initial growth of I to an exponent function, the fitting is carried out using Xmgrace
# As the plot shows, the initai growth is almost exponential, withe an exponential factor 0.48069. In fact, it's expected the initial exponential growth is beta-v which equals to 0.5, the 0.48069 is indeed, close to 0.5.
# N-S(infinite t limit)=0.965, corresponds to the size of the epidemic. It's not necessary for S to drop to zero since there can be possibility that some people don't get infected in a epidemic

# %%
import matplotlib.image as mpimg
Ifit=mpimg.imread('Question3Plot.png')
plt.figure(figsize=(14,18))
plt.imshow(Ifit)
print(max(infe+reco))

plt.figure(figsize=(8,8))
plt.scatter(T,infe+reco,label="N-S")
plt.xlabel("Time",fontsize=16)
plt.ylabel("N-S",fontsize=16)
plt.legend(fontsize=16)
# Out:
# 0.9652272399453647

# %% [markdown]
# # For question 4, we can plot the the SIR figure for different beta values.
# Since when beta* S[0] is smaller than v, an epidemic won't happen.
# The following code is a little bit naive, I may try to clean it a little bit if I have time.

# %%
v=0.2
S=0.9999
I=0.0001
R=0
deltaT=1
days=400
suscb1=np.zeros(400)
infeb1=np.zeros(400)
recob1=np.zeros(400)
suscb1[0]=S
infeb1[0]=I
recob1[0]=R
for i in range(399):
    beta=0.05
    suscb1[i+1]=PCS(beta,suscb1[i],infeb1[i],v,deltaT)
    infeb1[i+1]=PCI(beta,suscb1[i],infeb1[i],v,deltaT)
    recob1[i+1]=PCR(suscb1[i],infeb1[i],recob1[i],v,deltaT)

# %%
suscb2=np.zeros(400)
infeb2=np.zeros(400)
recob2=np.zeros(400)
suscb2[0]=S
infeb2[0]=I
recob2[0]=R
for i in range(399):
    beta=0.1
    suscb2[i+1]=PCS(beta,suscb2[i],infeb2[i],v,deltaT)
    infeb2[i+1]=PCI(beta,suscb2[i],infeb2[i],v,deltaT)
    recob2[i+1]=PCR(suscb2[i],infeb2[i],recob2[i],v,deltaT)

# %%
suscb3=np.zeros(400)
infeb3=np.zeros(400)
recob3=np.zeros(400)
suscb3[0]=S
infeb3[0]=I
recob3[0]=R
for i in range(399):
    beta=0.2
    suscb3[i+1]=PCS(beta,suscb3[i],infeb3[i],v,deltaT)
    infeb3[i+1]=PCI(beta,suscb3[i],infeb3[i],v,deltaT)
    recob3[i+1]=PCR(suscb3[i],infeb3[i],recob3[i],v,deltaT)

# %%
suscb4=np.zeros(400)
infeb4=np.zeros(400)
recob4=np.zeros(400)
suscb4[0]=S
infeb4[0]=I
recob4[0]=R
for i in range(399):
    beta=0.3
    suscb4[i+1]=PCS(beta,suscb4[i],infeb4[i],v,deltaT)
    infeb4[i+1]=PCI(beta,suscb4[i],infeb4[i],v,deltaT)
    recob4[i+1]=PCR(suscb4[i],infeb4[i],recob4[i],v,deltaT)

# %%
suscb5=np.zeros(400)
infeb5=np.zeros(400)
recob5=np.zeros(400)
suscb5[0]=S
infeb5[0]=I
recob5[0]=R
for i in range(399):
    beta=0.4
    suscb5[i+1]=PCS(beta,suscb5[i],infeb5[i],v,deltaT)
    infeb5[i+1]=PCI(beta,suscb5[i],infeb5[i],v,deltaT)
    recob5[i+1]=PCR(suscb5[i],infeb5[i],recob5[i],v,deltaT)

# %%
suscb6=np.zeros(400)
infeb6=np.zeros(400)
recob6=np.zeros(400)
suscb6[0]=S
infeb6[0]=I
recob6[0]=R
for i in range(399):
    beta=0.5
    suscb6[i+1]=PCS(beta,suscb6[i],infeb6[i],v,deltaT)
    infeb6[i+1]=PCI(beta,suscb6[i],infeb6[i],v,deltaT)
    recob6[i+1]=PCR(suscb6[i],infeb6[i],recob6[i],v,deltaT)

# %%
T2=np.linspace(1,400,400)
plt.figure(figsize=(30,20))
plt.subplot(231)
plt.scatter(T2,suscb1,color="Red",linewidth="3",label="Susceptible")
plt.scatter(T2,infeb1,color="Yellow",linewidth="3",label="Infected")
plt.scatter(T2,recob1,color="blue",linewidth="3",label="Recovered")
plt.title("DeltaT=1, beta=0.05")
plt.xlabel("Time(Days)")
plt.ylabel("Percentage of People")
plt.legend()
plt.subplot(232)
plt.scatter(T2,suscb2,color="Red",linewidth="3",label="Susceptible")
plt.scatter(T2,infeb2,color="Yellow",linewidth="3",label="Infected")
plt.scatter(T2,recob2,color="blue",linewidth="3",label="Recovered")
plt.title("DeltaT=1, beta=0.1")
plt.xlabel("Time(Days)")
plt.ylabel("Percentage of People")
plt.legend()
plt.subplot(233)
plt.scatter(T2,suscb3,color="Red",linewidth="3",label="Susceptible")
plt.scatter(T2,infeb3,color="Yellow",linewidth="3",label="Infected")
plt.scatter(T2,recob3,color="blue",linewidth="3",label="Recovered")
plt.title("DeltaT=1, beta=0.2")
plt.xlabel("Time(Days)")
plt.ylabel("Percentage of People")
plt.legend()
plt.subplot(234)
plt.scatter(T2,suscb4,color="Red",linewidth="3",label="Susceptible")
plt.scatter(T2,infeb4,color="Yellow",linewidth="3",label="Infected")
plt.scatter(T2,recob4,color="blue",linewidth="3",label="Recovered")
plt.title("DeltaT=1, beta=0.3")
plt.xlabel("Time(Days)")
plt.ylabel("Percentage of People")
plt.legend()
plt.subplot(235)
plt.scatter(T2,suscb5,color="Red",linewidth="3",label="Susceptible")
plt.scatter(T2,infeb5,color="Yellow",linewidth="3",label="Infected")
plt.scatter(T2,recob5,color="blue",linewidth="3",label="Recovered")
plt.title("DeltaT=1, beta=0.4")
plt.xlabel("Time(Days)")
plt.ylabel("Percentage of People")
plt.legend()
plt.subplot(236)
plt.scatter(T2,suscb6,color="Red",linewidth="3",label="Susceptible")
plt.scatter(T2,infeb6,color="Yellow",linewidth="3",label="Infected")
plt.scatter(T2,recob6,color="blue",linewidth="3",label="Recovered")
plt.title("DeltaT=1, beta=0.5")
plt.xlabel("Time(Days)")
plt.ylabel("Percentage of People")
plt.legend()

# %% [markdown]
# # For question 5 We select different p values to see if certain p can prevent an epidemic, we choose beta=0.5 and v=0.2 in this case

# %%
susc=np.zeros(200)
infe=np.zeros(200)
reco=np.zeros(200)
S=0.9999
I=0.0001
R=0.9999
p=0.1
susc[0]=S*(1-p)
infe[0]=I
reco[0]=R*p
for i in range(199):
    beta=0.5
    susc[i+1]=PCS(beta,susc[i],infe[i],v,deltaT)
    infe[i+1]=PCI(beta,susc[i],infe[i],v,deltaT)
    reco[i+1]=PCR(susc[i],infe[i],reco[i],v,deltaT)
suscp1=susc
infep1=infe
recop1=reco

# %%
susc=np.zeros(200)
infe=np.zeros(200)
reco=np.zeros(200)
S=0.9999
I=0.0001
R=0.9999
p=0.2
susc[0]=S*(1-p)
infe[0]=I
reco[0]=R*p
for i in range(199):
    beta=0.5
    susc[i+1]=PCS(beta,susc[i],infe[i],v,deltaT)
    infe[i+1]=PCI(beta,susc[i],infe[i],v,deltaT)
    reco[i+1]=PCR(susc[i],infe[i],reco[i],v,deltaT)
suscp2=susc
infep2=infe
recop2=reco

# %%
susc=np.zeros(200)
infe=np.zeros(200)
reco=np.zeros(200)
S=0.9999
I=0.0001
R=0.9999
p=0.3
susc[0]=S*(1-p)
infe[0]=I
reco[0]=R*p
for i in range(199):
    beta=0.5
    susc[i+1]=PCS(beta,susc[i],infe[i],v,deltaT)
    infe[i+1]=PCI(beta,susc[i],infe[i],v,deltaT)
    reco[i+1]=PCR(susc[i],infe[i],reco[i],v,deltaT)
suscp3=susc
infep3=infe
recop3=reco

# %%
susc=np.zeros(200)
infe=np.zeros(200)
reco=np.zeros(200)
S=0.9999
I=0.0001
R=0.9999
p=0.4
susc[0]=S*(1-p)
infe[0]=I
reco[0]=R*p
for i in range(199):
    beta=0.5
    susc[i+1]=PCS(beta,susc[i],infe[i],v,deltaT)
    infe[i+1]=PCI(beta,susc[i],infe[i],v,deltaT)
    reco[i+1]=PCR(susc[i],infe[i],reco[i],v,deltaT)
suscp4=susc
infep4=infe
recop4=reco

# %%
susc=np.zeros(200)
infe=np.zeros(200)
reco=np.zeros(200)
S=0.9999
I=0.0001
R=0.9999
p=0.5
susc[0]=S*(1-p)
infe[0]=I
reco[0]=R*p
for i in range(199):
    beta=0.5
    susc[i+1]=PCS(beta,susc[i],infe[i],v,deltaT)
    infe[i+1]=PCI(beta,susc[i],infe[i],v,deltaT)
    reco[i+1]=PCR(susc[i],infe[i],reco[i],v,deltaT)
suscp5=susc
infep5=infe
recop5=reco

# %%
susc=np.zeros(200)
infe=np.zeros(200)
reco=np.zeros(200)
S=0.9999
I=0.0001
R=0.9999
p=0.6
susc[0]=S*(1-p)
infe[0]=I
reco[0]=R*p
for i in range(199):
    beta=0.5
    susc[i+1]=PCS(beta,susc[i],infe[i],v,deltaT)
    infe[i+1]=PCI(beta,susc[i],infe[i],v,deltaT)
    reco[i+1]=PCR(susc[i],infe[i],reco[i],v,deltaT)
suscp6=susc
infep6=infe
recop6=reco

# %%
susc=np.zeros(200)
infe=np.zeros(200)
reco=np.zeros(200)
S=0.9999
I=0.0001
R=0.9999
p=0.7
susc[0]=S*(1-p)
infe[0]=I
reco[0]=R*p
for i in range(199):
    beta=0.5
    susc[i+1]=PCS(beta,susc[i],infe[i],v,deltaT)
    infe[i+1]=PCI(beta,susc[i],infe[i],v,deltaT)
    reco[i+1]=PCR(susc[i],infe[i],reco[i],v,deltaT)
suscp7=susc
infep7=infe
recop7=reco

# %%
susc=np.zeros(200)
infe=np.zeros(200)
reco=np.zeros(200)
S=0.9999
I=0.0001
R=0.9999
p=0.8
susc[0]=S*(1-p)
infe[0]=I
reco[0]=R*p
for i in range(199):
    beta=0.5
    susc[i+1]=PCS(beta,susc[i],infe[i],v,deltaT)
    infe[i+1]=PCI(beta,susc[i],infe[i],v,deltaT)
    reco[i+1]=PCR(susc[i],infe[i],reco[i],v,deltaT)
suscp8=susc
infep8=infe
recop8=reco

# %%
T3=np.linspace(1,200,200)
plt.figure(figsize=(24,48))
plt.subplot(421)
plt.scatter(T3,suscp1,color="Red",linewidth="3",label="Susceptible")
plt.scatter(T3,infep1,color="Yellow",linewidth="3",label="Infected")
plt.scatter(T3,recop1,color="blue",linewidth="3",label="Recovered")
plt.title("DeltaT=1, beta=0.5,v=0.2,p=0.1",fontsize=20)
plt.xlabel("Time(Days)",fontsize=16)
plt.ylabel("Percentage of People",fontsize=16)
plt.legend(fontsize=16)
plt.subplot(422)
plt.scatter(T3,suscp2,color="Red",linewidth="3",label="Susceptible")
plt.scatter(T3,infep2,color="Yellow",linewidth="3",label="Infected")
plt.scatter(T3,recop2,color="blue",linewidth="3",label="Recovered")
plt.title("DeltaT=1, beta=0.5,v=0.2,p=0.2",fontsize=20)
plt.xlabel("Time(Days)",fontsize=16)
plt.ylabel("Percentage of People",fontsize=16)
plt.legend(fontsize=16)
plt.subplot(423)
plt.scatter(T3,suscp3,color="Red",linewidth="3",label="Susceptible")
plt.scatter(T3,infep3,color="Yellow",linewidth="3",label="Infected")
plt.scatter(T3,recop3,color="blue",linewidth="3",label="Recovered")
plt.title("DeltaT=1, beta=0.5,v=0.2,p=0.3",fontsize=20)
plt.xlabel("Time(Days)",fontsize=16)
plt.ylabel("Percentage of People",fontsize=16)
plt.legend(fontsize=16)
plt.subplot(424)
plt.scatter(T3,suscp4,color="Red",linewidth="3",label="Susceptible")
plt.scatter(T3,infep4,color="Yellow",linewidth="3",label="Infected")
plt.scatter(T3,recop4,color="blue",linewidth="3",label="Recovered")
plt.title("DeltaT=1, beta=0.5,v=0.2,p=0.4",fontsize=20)
plt.xlabel("Time(Days)",fontsize=16)
plt.ylabel("Percentage of People",fontsize=16)
plt.legend(fontsize=16)
plt.subplot(425)
plt.scatter(T3,suscp5,color="Red",linewidth="3",label="Susceptible")
plt.scatter(T3,infep5,color="Yellow",linewidth="3",label="Infected")
plt.scatter(T3,recop5,color="blue",linewidth="3",label="Recovered")
plt.title("DeltaT=1, beta=0.5,v=0.2,p=0.5",fontsize=20)
plt.xlabel("Time(Days)",fontsize=16)
plt.ylabel("Percentage of People",fontsize=16)
plt.legend(fontsize=16)
plt.subplot(426)
plt.scatter(T3,suscp6,color="Red",linewidth="3",label="Susceptible")
plt.scatter(T3,infep6,color="Yellow",linewidth="3",label="Infected")
plt.scatter(T3,recop6,color="blue",linewidth="3",label="Recovered")
plt.title("DeltaT=1, beta=0.5,v=0.2,p=0.6",fontsize=20)
plt.xlabel("Time(Days)",fontsize=16)
plt.ylabel("Percentage of People",fontsize=16)
plt.legend(fontsize=16)
plt.subplot(427)
plt.scatter(T3,suscp7,color="Red",linewidth="3",label="Susceptible")
plt.scatter(T3,infep7,color="Yellow",linewidth="3",label="Infected")
plt.scatter(T3,recop7,color="blue",linewidth="3",label="Recovered")
plt.title("DeltaT=1, beta=0.5,v=0.2,p=0.7",fontsize=20)
plt.xlabel("Time(Days)",fontsize=16)
plt.ylabel("Percentage of People",fontsize=16)
plt.legend(fontsize=16)
plt.subplot(428)
plt.scatter(T3,suscp8,color="Red",linewidth="3",label="Susceptible")
plt.scatter(T3,infep8,color="Yellow",linewidth="3",label="Infected")
plt.scatter(T3,recop8,color="blue",linewidth="3",label="Recovered")
plt.title("DeltaT=1, beta=0.5,v=0.2,p=0.8",fontsize=20)
plt.xlabel("Time(Days)",fontsize=16)
plt.ylabel("Percentage of People",fontsize=16)
plt.legend(fontsize=16)

# %% [markdown]
# # I increase beta=0.7, and repeat the above step

# %%
susc=np.zeros(200)
infe=np.zeros(200)
reco=np.zeros(200)
S=0.9999
I=0.0001
R=0.9999
p=0.1
susc[0]=S*(1-p)
infe[0]=I
reco[0]=R*p
for i in range(199):
    beta=0.7
    susc[i+1]=PCS(beta,susc[i],infe[i],v,deltaT)
    infe[i+1]=PCI(beta,susc[i],infe[i],v,deltaT)
    reco[i+1]=PCR(susc[i],infe[i],reco[i],v,deltaT)
suscp11=susc
infep11=infe
recop11=reco

# %%
susc=np.zeros(200)
infe=np.zeros(200)
reco=np.zeros(200)
S=0.9999
I=0.0001
R=0.9999
p=0.2
susc[0]=S*(1-p)
infe[0]=I
reco[0]=R*p
for i in range(199):
    beta=0.7
    susc[i+1]=PCS(beta,susc[i],infe[i],v,deltaT)
    infe[i+1]=PCI(beta,susc[i],infe[i],v,deltaT)
    reco[i+1]=PCR(susc[i],infe[i],reco[i],v,deltaT)
suscp12=susc
infep12=infe
recop12=reco
susc=np.zeros(200)
infe=np.zeros(200)
reco=np.zeros(200)
S=0.9999
I=0.0001
R=0.9999
p=0.3
susc[0]=S*(1-p)
infe[0]=I
reco[0]=R*p
for i in range(199):
    beta=0.7
    susc[i+1]=PCS(beta,susc[i],infe[i],v,deltaT)
    infe[i+1]=PCI(beta,susc[i],infe[i],v,deltaT)
    reco[i+1]=PCR(susc[i],infe[i],reco[i],v,deltaT)
suscp13=susc
infep13=infe
recop13=reco
susc=np.zeros(200)
infe=np.zeros(200)
reco=np.zeros(200)
S=0.9999
I=0.0001
R=0.9999
p=0.4
susc[0]=S*(1-p)
infe[0]=I
reco[0]=R*p
for i in range(199):
    beta=0.7
    susc[i+1]=PCS(beta,susc[i],infe[i],v,deltaT)
    infe[i+1]=PCI(beta,susc[i],infe[i],v,deltaT)
    reco[i+1]=PCR(susc[i],infe[i],reco[i],v,deltaT)
suscp14=susc
infep14=infe
recop14=reco
susc=np.zeros(200)
infe=np.zeros(200)
reco=np.zeros(200)
S=0.9999
I=0.0001
R=0.9999
p=0.5
susc[0]=S*(1-p)
infe[0]=I
reco[0]=R*p
for i in range(199):
    beta=0.7
    susc[i+1]=PCS(beta,susc[i],infe[i],v,deltaT)
    infe[i+1]=PCI(beta,susc[i],infe[i],v,deltaT)
    reco[i+1]=PCR(susc[i],infe[i],reco[i],v,deltaT)
suscp15=susc
infep15=infe
recop15=reco
susc=np.zeros(200)
infe=np.zeros(200)
reco=np.zeros(200)
S=0.9999
I=0.0001
R=0.9999
p=0.6
susc[0]=S*(1-p)
infe[0]=I
reco[0]=R*p
for i in range(199):
    beta=0.7
    susc[i+1]=PCS(beta,susc[i],infe[i],v,deltaT)
    infe[i+1]=PCI(beta,susc[i],infe[i],v,deltaT)
    reco[i+1]=PCR(susc[i],infe[i],reco[i],v,deltaT)
suscp16=susc
infep16=infe
recop16=reco
susc=np.zeros(200)
infe=np.zeros(200)
reco=np.zeros(200)
S=0.9999
I=0.0001
R=0.9999
p=0.7
susc[0]=S*(1-p)
infe[0]=I
reco[0]=R*p
for i in range(199):
    beta=0.7
    susc[i+1]=PCS(beta,susc[i],infe[i],v,deltaT)
    infe[i+1]=PCI(beta,susc[i],infe[i],v,deltaT)
    reco[i+1]=PCR(susc[i],infe[i],reco[i],v,deltaT)
suscp17=susc
infep17=infe
recop17=reco
susc=np.zeros(200)
infe=np.zeros(200)
reco=np.zeros(200)
S=0.9999
I=0.0001
R=0.9999
p=0.8
susc[0]=S*(1-p)
infe[0]=I
reco[0]=R*p
for i in range(199):
    beta=0.7
    susc[i+1]=PCS(beta,susc[i],infe[i],v,deltaT)
    infe[i+1]=PCI(beta,susc[i],infe[i],v,deltaT)
    reco[i+1]=PCR(susc[i],infe[i],reco[i],v,deltaT)
suscp18=susc
infep18=infe
recop18=reco

# %%
T3=np.linspace(1,200,200)
plt.figure(figsize=(24,48))
plt.subplot(421)
plt.scatter(T3,suscp11,color="Red",linewidth="3",label="Susceptible")
plt.scatter(T3,infep11,color="Yellow",linewidth="3",label="Infected")
plt.scatter(T3,recop11,color="blue",linewidth="3",label="Recovered")
plt.title("DeltaT=1, beta=0.7,v=0.2,p=0.1",fontsize=20)
plt.xlabel("Time(Days)",fontsize=16)
plt.ylabel("Percentage of People",fontsize=16)
plt.legend(fontsize=16)
plt.subplot(422)
plt.scatter(T3,suscp12,color="Red",linewidth="3",label="Susceptible")
plt.scatter(T3,infep12,color="Yellow",linewidth="3",label="Infected")
plt.scatter(T3,recop12,color="blue",linewidth="3",label="Recovered")
plt.title("DeltaT=1, beta=0.7,v=0.2,p=0.2",fontsize=20)
plt.xlabel("Time(Days)",fontsize=16)
plt.ylabel("Percentage of People",fontsize=16)
plt.legend(fontsize=16)
plt.subplot(423)
plt.scatter(T3,suscp13,color="Red",linewidth="3",label="Susceptible")
plt.scatter(T3,infep13,color="Yellow",linewidth="3",label="Infected")
plt.scatter(T3,recop13,color="blue",linewidth="3",label="Recovered")
plt.title("DeltaT=1, beta=0.7,v=0.2,p=0.3",fontsize=20)
plt.xlabel("Time(Days)",fontsize=16)
plt.ylabel("Percentage of People",fontsize=16)
plt.legend(fontsize=16)
plt.subplot(424)
plt.scatter(T3,suscp14,color="Red",linewidth="3",label="Susceptible")
plt.scatter(T3,infep14,color="Yellow",linewidth="3",label="Infected")
plt.scatter(T3,recop14,color="blue",linewidth="3",label="Recovered")
plt.title("DeltaT=1, beta=0.7,v=0.2,p=0.4",fontsize=20)
plt.xlabel("Time(Days)",fontsize=16)
plt.ylabel("Percentage of People",fontsize=16)
plt.legend(fontsize=16)
plt.subplot(425)
plt.scatter(T3,suscp15,color="Red",linewidth="3",label="Susceptible")
plt.scatter(T3,infep15,color="Yellow",linewidth="3",label="Infected")
plt.scatter(T3,recop15,color="blue",linewidth="3",label="Recovered")
plt.title("DeltaT=1, beta=0.7,v=0.2,p=0.5",fontsize=20)
plt.xlabel("Time(Days)",fontsize=16)
plt.ylabel("Percentage of People",fontsize=16)
plt.legend(fontsize=16)
plt.subplot(426)
plt.scatter(T3,suscp16,color="Red",linewidth="3",label="Susceptible")
plt.scatter(T3,infep16,color="Yellow",linewidth="3",label="Infected")
plt.scatter(T3,recop16,color="blue",linewidth="3",label="Recovered")
plt.title("DeltaT=1, beta=0.7,v=0.2,p=0.6",fontsize=20)
plt.xlabel("Time(Days)",fontsize=16)
plt.ylabel("Percentage of People",fontsize=16)
plt.legend(fontsize=16)
plt.subplot(427)
plt.scatter(T3,suscp17,color="Red",linewidth="3",label="Susceptible")
plt.scatter(T3,infep17,color="Yellow",linewidth="3",label="Infected")
plt.scatter(T3,recop17,color="blue",linewidth="3",label="Recovered")
plt.title("DeltaT=1, beta=0.7,v=0.2,p=0.7",fontsize=20)
plt.xlabel("Time(Days)",fontsize=16)
plt.ylabel("Percentage of People",fontsize=16)
plt.legend(fontsize=16)
plt.subplot(428)
plt.scatter(T3,suscp18,color="Red",linewidth="3",label="Susceptible")
plt.scatter(T3,infep18,color="Yellow",linewidth="3",label="Infected")
plt.scatter(T3,recop18,color="blue",linewidth="3",label="Recovered")
plt.title("DeltaT=1, beta=0.7,v=0.2,p=0.8",fontsize=20)
plt.xlabel("Time(Days)",fontsize=16)
plt.ylabel("Percentage of People",fontsize=16)
plt.legend(fontsize=16)

# %% [markdown]
# # Decrese beta=0.3, repeat the above step

# %%
susc=np.zeros(200)
infe=np.zeros(200)
reco=np.zeros(200)
S=0.9999
I=0.0001
R=0.9999
p=0.1
susc[0]=S*(1-p)
infe[0]=I
reco[0]=R*p
for i in range(199):
    beta=0.3
    susc[i+1]=PCS(beta,susc[i],infe[i],v,deltaT)
    infe[i+1]=PCI(beta,susc[i],infe[i],v,deltaT)
    reco[i+1]=PCR(susc[i],infe[i],reco[i],v,deltaT)
suscp21=susc
infep21=infe
recop21=reco
susc=np.zeros(200)
infe=np.zeros(200)
reco=np.zeros(200)
S=0.9999
I=0.0001
R=0.9999
p=0.2
susc[0]=S*(1-p)
infe[0]=I
reco[0]=R*p
for i in range(199):
    beta=0.3
    susc[i+1]=PCS(beta,susc[i],infe[i],v,deltaT)
    infe[i+1]=PCI(beta,susc[i],infe[i],v,deltaT)
    reco[i+1]=PCR(susc[i],infe[i],reco[i],v,deltaT)
suscp22=susc
infep22=infe
recop22=reco
susc=np.zeros(200)
infe=np.zeros(200)
reco=np.zeros(200)
S=0.9999
I=0.0001
R=0.9999
p=0.3
susc[0]=S*(1-p)
infe[0]=I
reco[0]=R*p
for i in range(199):
    beta=0.3
    susc[i+1]=PCS(beta,susc[i],infe[i],v,deltaT)
    infe[i+1]=PCI(beta,susc[i],infe[i],v,deltaT)
    reco[i+1]=PCR(susc[i],infe[i],reco[i],v,deltaT)
suscp23=susc
infep23=infe
recop23=reco
susc=np.zeros(200)
infe=np.zeros(200)
reco=np.zeros(200)
S=0.9999
I=0.0001
R=0.9999
p=0.4
susc[0]=S*(1-p)
infe[0]=I
reco[0]=R*p
for i in range(199):
    beta=0.3
    susc[i+1]=PCS(beta,susc[i],infe[i],v,deltaT)
    infe[i+1]=PCI(beta,susc[i],infe[i],v,deltaT)
    reco[i+1]=PCR(susc[i],infe[i],reco[i],v,deltaT)
suscp24=susc
infep24=infe
recop24=reco
susc=np.zeros(200)
infe=np.zeros(200)
reco=np.zeros(200)
S=0.9999
I=0.0001
R=0.9999
p=0.5
susc[0]=S*(1-p)
infe[0]=I
reco[0]=R*p
for i in range(199):
    beta=0.3
    susc[i+1]=PCS(beta,susc[i],infe[i],v,deltaT)
    infe[i+1]=PCI(beta,susc[i],infe[i],v,deltaT)
    reco[i+1]=PCR(susc[i],infe[i],reco[i],v,deltaT)
suscp25=susc
infep25=infe
recop25=reco
susc=np.zeros(200)
infe=np.zeros(200)
reco=np.zeros(200)
S=0.9999
I=0.0001
R=0.9999
p=0.6
susc[0]=S*(1-p)
infe[0]=I
reco[0]=R*p
for i in range(199):
    beta=0.3
    susc[i+1]=PCS(beta,susc[i],infe[i],v,deltaT)
    infe[i+1]=PCI(beta,susc[i],infe[i],v,deltaT)
    reco[i+1]=PCR(susc[i],infe[i],reco[i],v,deltaT)
suscp26=susc
infep26=infe
recop26=reco
susc=np.zeros(200)
infe=np.zeros(200)
reco=np.zeros(200)
S=0.9999
I=0.0001
R=0.9999
p=0.7
susc[0]=S*(1-p)
infe[0]=I
reco[0]=R*p
for i in range(199):
    beta=0.3
    susc[i+1]=PCS(beta,susc[i],infe[i],v,deltaT)
    infe[i+1]=PCI(beta,susc[i],infe[i],v,deltaT)
    reco[i+1]=PCR(susc[i],infe[i],reco[i],v,deltaT)
suscp27=susc
infep27=infe
recop27=reco
susc=np.zeros(200)
infe=np.zeros(200)
reco=np.zeros(200)
S=0.9999
I=0.0001
R=0.9999
p=0.8
susc[0]=S*(1-p)
infe[0]=I
reco[0]=R*p
for i in range(199):
    beta=0.3
    susc[i+1]=PCS(beta,susc[i],infe[i],v,deltaT)
    infe[i+1]=PCI(beta,susc[i],infe[i],v,deltaT)
    reco[i+1]=PCR(susc[i],infe[i],reco[i],v,deltaT)
suscp28=susc
infep28=infe
recop28=reco

# %%
T3=np.linspace(1,200,200)
plt.figure(figsize=(24,48))
plt.subplot(421)
plt.scatter(T3,suscp21,color="Red",linewidth="3",label="Susceptible")
plt.scatter(T3,infep21,color="Yellow",linewidth="3",label="Infected")
plt.scatter(T3,recop21,color="blue",linewidth="3",label="Recovered")
plt.title("DeltaT=1, beta=0.3,v=0.2,p=0.1",fontsize=20)
plt.xlabel("Time(Days)",fontsize=16)
plt.ylabel("Percentage of People",fontsize=16)
plt.legend(fontsize=16)
plt.subplot(422)
plt.scatter(T3,suscp22,color="Red",linewidth="3",label="Susceptible")
plt.scatter(T3,infep22,color="Yellow",linewidth="3",label="Infected")
plt.scatter(T3,recop22,color="blue",linewidth="3",label="Recovered")
plt.title("DeltaT=1, beta=0.3,v=0.2,p=0.2",fontsize=20)
plt.xlabel("Time(Days)",fontsize=16)
plt.ylabel("Percentage of People",fontsize=16)
plt.legend(fontsize=16)
plt.subplot(423)
plt.scatter(T3,suscp23,color="Red",linewidth="3",label="Susceptible")
plt.scatter(T3,infep23,color="Yellow",linewidth="3",label="Infected")
plt.scatter(T3,recop23,color="blue",linewidth="3",label="Recovered")
plt.title("DeltaT=1, beta=0.3,v=0.2,p=0.3",fontsize=20)
plt.xlabel("Time(Days)",fontsize=16)
plt.ylabel("Percentage of People",fontsize=16)
plt.legend(fontsize=16)
plt.subplot(424)
plt.scatter(T3,suscp24,color="Red",linewidth="3",label="Susceptible")
plt.scatter(T3,infep24,color="Yellow",linewidth="3",label="Infected")
plt.scatter(T3,recop24,color="blue",linewidth="3",label="Recovered")
plt.title("DeltaT=1, beta=0.3,v=0.2,p=0.4",fontsize=20)
plt.xlabel("Time(Days)",fontsize=16)
plt.ylabel("Percentage of People",fontsize=16)
plt.legend(fontsize=16)
plt.subplot(425)
plt.scatter(T3,suscp25,color="Red",linewidth="3",label="Susceptible")
plt.scatter(T3,infep25,color="Yellow",linewidth="3",label="Infected")
plt.scatter(T3,recop25,color="blue",linewidth="3",label="Recovered")
plt.title("DeltaT=1, beta=0.3,v=0.2,p=0.5",fontsize=20)
plt.xlabel("Time(Days)",fontsize=16)
plt.ylabel("Percentage of People",fontsize=16)
plt.legend(fontsize=16)
plt.subplot(426)
plt.scatter(T3,suscp26,color="Red",linewidth="3",label="Susceptible")
plt.scatter(T3,infep26,color="Yellow",linewidth="3",label="Infected")
plt.scatter(T3,recop26,color="blue",linewidth="3",label="Recovered")
plt.title("DeltaT=1, beta=0.3,v=0.2,p=0.6",fontsize=20)
plt.xlabel("Time(Days)",fontsize=16)
plt.ylabel("Percentage of People",fontsize=16)
plt.legend(fontsize=16)
plt.subplot(427)
plt.scatter(T3,suscp27,color="Red",linewidth="3",label="Susceptible")
plt.scatter(T3,infep27,color="Yellow",linewidth="3",label="Infected")
plt.scatter(T3,recop27,color="blue",linewidth="3",label="Recovered")
plt.title("DeltaT=1, beta=0.3,v=0.2,p=0.7",fontsize=20)
plt.xlabel("Time(Days)",fontsize=16)
plt.ylabel("Percentage of People",fontsize=16)
plt.legend(fontsize=16)
plt.subplot(428)
plt.scatter(T3,suscp28,color="Red",linewidth="3",label="Susceptible")
plt.scatter(T3,infep28,color="Yellow",linewidth="3",label="Infected")
plt.scatter(T3,recop28,color="blue",linewidth="3",label="Recovered")
plt.title("DeltaT=1, beta=0.3,v=0.2,p=0.8",fontsize=20)
plt.xlabel("Time(Days)",fontsize=16)
plt.ylabel("Percentage of People",fontsize=16)
plt.legend(fontsize=16)

# %% [markdown]
# #  Define the PC algorithm for m=0.001

# %%
def PCSm(beta,S,I,v,m,t):  #PC method for Susceptibile 
    Spre=S-(beta*S*I-m+m*S)*t #predictor
    Ipre=I+(beta*S*I-v*I-m*I)*t #predictor
    Scor=S-(beta*S*I+beta*Spre*Ipre)*t/2+(2*m-m*S-m*Spre)*t/2  #corrector
    return Scor

def PCIm(beta,S,I,v,m,t):  #PC method for infected
    Spre=S-(beta*S*I+m-m*S)*t #predictor
    Ipre=I+(beta*S*I-v*I-m*I)*t  #predictor
    Icor=I+(beta*S*I-v*I+beta*Spre*Ipre-v*Ipre-m*I-m*Ipre)*t/2  #corrector
    return Icor

def PCRm(S,I,R,v,m,t): #PC method for recovered
    Rpre=R+(v*I-m*R)*t  #predictor
    Ipre=I+(beta*S*I-v*I-m*I)*t  #predictor
    Rcor=R+(v*I+v*Ipre-m*R-m*Rpre)*t/2  #corrector
    return Rcor

# %% [markdown]
# Set beta=0.7, v=0.2 so it's easier to compare with previous result. No big difference is observed.

# %%
suscm1=np.zeros(200)
infem1=np.zeros(200)
recom1=np.zeros(200)
S=0.9999
I=0.0001
R=0
suscm1[0]=S
infem1[0]=I
recom1[0]=R
betam1=0.7
vm1=0.2
m1=0.001
for i in range(199):
    suscm1[i+1]=PCSm(betam1,suscm1[i],infem1[i],vm1,m1,deltaT)
    infem1[i+1]=PCIm(betam1,suscm1[i],infem1[i],vm1,m1,deltaT)
    recom1[i+1]=PCRm(suscm1[i],infem1[i],recom1[i],vm1,m1,deltaT)

plt.figure(figsize=(12,12))
plt.scatter(T3,suscm1,color="Red",linewidth="3",label="Susceptible")
plt.scatter(T3,infem1,color="green",linewidth="3",label="Infected")
plt.scatter(T3,recom1,color="blue",linewidth="3",label="Removed")
plt.plot(T,susc,color="Red",linewidth="2",label="Susceptible m=0")
plt.plot(T,infe,color="green",linewidth="2",label="Infected m=0")
plt.plot(T,reco,color="blue",linewidth="2",label="Removed m=0")
plt.title("DeltaT=1, beta=0.7,m=0.001,v=0.2",fontsize=20)
plt.xlabel("Time(Days)",fontsize=16)
plt.ylabel("Percentage of People",fontsize=16)
plt.legend(fontsize=16)

# %% [markdown]
# Consider a less virulent flu, set beta=0.5,v=0.2
# Seems controlling the birth rate will be an good idea

# %%
T4=np.linspace(1,1000,1000)
suscm2=np.zeros(1000)
infem2=np.zeros(1000)
recom2=np.zeros(1000)
S=0.9999
I=0.0001
R=0
suscm2[0]=S
infem2[0]=I
recom2[0]=R
betam2=0.5
vm1=0.2
m2=0.001
for i in range(999):
    suscm2[i+1]=PCSm(betam2,suscm2[i],infem2[i],vm1,m2,deltaT)
    infem2[i+1]=PCIm(betam2,suscm2[i],infem2[i],vm1,m2,deltaT)
    recom2[i+1]=PCRm(suscm2[i],infem2[i],recom2[i],vm1,m2,deltaT)

suscm3=np.zeros(1000)
infem3=np.zeros(1000)
recom3=np.zeros(1000)
suscm3[0]=S
infem3[0]=I
recom3[0]=R
betam3=0.5
vm3=0.2
m3=0.005
for i in range(999):
    suscm3[i+1]=PCSm(betam3,suscm3[i],infem3[i],vm3,m3,deltaT)
    infem3[i+1]=PCIm(betam3,suscm3[i],infem3[i],vm3,m3,deltaT)
    recom3[i+1]=PCRm(suscm3[i],infem3[i],recom3[i],vm3,m3,deltaT)
plt.figure(figsize=(12,12))
plt.scatter(T4,suscm2,color="Red",linewidth="3",label="Susceptible m=0.001")
plt.scatter(T4,infem2,color="green",linewidth="3",label="Infected m=0.001")
plt.scatter(T4,recom2,color="blue",linewidth="3",label="Removed m=0.001")
plt.scatter(T4,suscm3,color="Red",marker="+",linewidth="1",label="Susceptible m=0.005")
plt.scatter(T4,infem3,color="green",marker="+",linewidth="1",label="Infected m=0.005")
plt.scatter(T4,recom3,color="blue",marker="+",linewidth="1",label="Removed m=0.005")
plt.plot(T2,suscb6,color="Red",linewidth="2",label="Susceptible m=0")
plt.plot(T2,infeb6,color="green",linewidth="2",label="Infected m=0")
plt.plot(T2,recob6,color="blue",linewidth="2",label="Recovered m=0")
plt.title("DeltaT=1, beta=0.5,v=0.2",fontsize=20)
plt.xlabel("Time(Days)",fontsize=16)
plt.ylabel("Percentage of People",fontsize=16)
plt.legend(fontsize=16)

# %% [markdown]
# # Fit the data

# %%
SIR=np.loadtxt("SIR.dat")

# %%
np.shape(SIR)
# Out:
# (61, 3)

# %%
print(tol)
# Out:
# 4294000.0

# %%
esusc=np.zeros(61)
einfe=np.zeros(61)
ereco=np.zeros(61)
tol=SIR[0][0]+SIR[0][1]+SIR[0][2]
for i in range(61):
    esusc[i]=SIR[i][0]/tol
    einfe[i]=SIR[i][1]/tol
    ereco[i]=SIR[i][2]/tol

Te=np.linspace(0,60,61)
plt.figure(figsize=(10,10))
plt.plot(Te,esusc,linewidth="2",label="Susceptible",color="Red")
plt.plot(Te,einfe,linewidth="2",label="Infected",color="green")
plt.plot(Te,ereco,linewidth="2",label="Removed",color="blue")
plt.title("Ebola data",fontsize=20)
plt.xlabel("Time(Days)",fontsize=16)
plt.ylabel("Percentage of People",fontsize=16)
plt.legend(fontsize=16)

# %%
EfitI=np.zeros((61,2))

# %%
for i in range(61):
    EfitI[i][0]=Te[i]
    EfitI[i][1]=einfe[i]
np.savetxt("Einfe.dat",EfitI)

# %%
Efit=mpimg.imread('Ebola fit.png')
plt.figure(figsize=(14,18))
plt.imshow(Efit)

# %% [markdown]
# The exponential factor is beta*S(0)-v=0.44638, while beta*S(infinite)-v=0
#
# we can estimate beta and v in this way

# %%
print(esusc[0])
print(esusc[60])
# Out:
# 0.9996318118304611
# 0.0003625989753143922

# %%
ebeta1=0.44638/(esusc[0]-esusc[21])
ev1=ebeta1*esusc[0]-0.44638

# %%
print(ebeta1)
print(ev1)
# Out:
# 0.5051735414516484
# 0.05860754253012179

# %%
fitesusc1=np.zeros(61)
fiteinfe1=np.zeros(61)
fitereco1=np.zeros(61)
fitesusc1[0]=esusc[0]
fiteinfe1[0]=einfe[0]
fitereco1[0]=ereco[0]
for i in range(60):
    fitesusc1[i+1]=PCS(ebeta1,fitesusc1[i],fiteinfe1[i],ev1,deltaT)
    fiteinfe1[i+1]=PCI(ebeta1,fitesusc1[i],fiteinfe1[i],ev1,deltaT)
    fitereco1[i+1]=PCR(fitesusc1[i],fiteinfe1[i],fitereco1[i],ev1,deltaT)
    
plt.figure(figsize=(12,12))
plt.scatter(Te,fitesusc1,linewidth="2",label="Susceptible fitted value",color="Red")
plt.scatter(Te,fiteinfe1,linewidth="2",label="Infected fitted value",color="green")
plt.scatter(Te,fitereco1,linewidth="2",label="Removed fitted value",color="blue")
plt.plot(Te,esusc,linewidth="2",label="Susceptible",color="Red")
plt.plot(Te,einfe,linewidth="2",label="Infected",color="green")
plt.plot(Te,ereco,linewidth="2",label="Removed",color="blue")
plt.title("Ebola data",fontsize=20)
plt.xlabel("Time(Days)",fontsize=16)
plt.ylabel("Percentage of People",fontsize=16)
plt.legend(fontsize=16)

# %% [markdown]
# # We search beta between 0.5 and 0.55, v between 0.05 and 0.08, with the minima distance being 0.001

# %%
testbeta0=np.linspace(0.5,0.6,101)
testv0=np.linspace(0.05,0.1,51)

# %%
error0=np.zeros(5151)
for i in range(101):
    for j in range(51):
        k=i*51+j
        tests=np.zeros(61)
        testi=np.zeros(61)
        testr=np.zeros(61)
        tests[0]=esusc[0]
        testi[0]=einfe[0]
        testr[0]=ereco[0]
        es=0
        ei=0
        er=0
        for l in range(60):
            tests[l+1]=PCS(testbeta0[i],tests[l],testi[l],testv0[j],deltaT)
            testi[l+1]=PCI(testbeta0[i],tests[l],testi[l],testv0[j],deltaT)
            testr[l+1]=PCR(tests[l],testi[l],testr[l],testv0[j],deltaT)
            es+=(tests[l+1]-esusc[l+1])**2
            ei+=(testi[l+1]-einfe[l+1])**2
            er+=(testr[l+1]-ereco[l+1])**2
        error0[k]=es+ei+er

# %%
print(np.where(error0==np.min(error0)))
# Out:
# (array([4944], dtype=int64),)

# %%
print(testbeta0[96])
print(testv0[48])
# Out:
# 0.596
# 0.098

# %%
fitesusc2=np.zeros(61)
fiteinfe2=np.zeros(61)
fitereco2=np.zeros(61)
fitesusc2[0]=esusc[0]
fiteinfe2[0]=einfe[0]
fitereco2[0]=ereco[0]
for i in range(60):
    fitesusc2[i+1]=PCS(0.596,fitesusc2[i],fiteinfe2[i],0.098,deltaT)
    fiteinfe2[i+1]=PCI(0.596,fitesusc2[i],fiteinfe2[i],0.098,deltaT)
    fitereco2[i+1]=PCR(fitesusc2[i],fiteinfe2[i],fitereco2[i],0.098,deltaT)
    
plt.figure(figsize=(12,12))
plt.scatter(Te,fitesusc2,linewidth="2",label="Susceptible fitted value",color="Red")
plt.scatter(Te,fiteinfe2,linewidth="2",label="Infected fitted value",color="green")
plt.scatter(Te,fitereco2,linewidth="2",label="Removed fitted value",color="blue")
plt.plot(Te,esusc,linewidth="2",label="Susceptible",color="Red")
plt.plot(Te,einfe,linewidth="2",label="Infected",color="green")
plt.plot(Te,ereco,linewidth="2",label="Removed",color="blue")
plt.title("Ebola data",fontsize=20)
plt.xlabel("Time(Days)",fontsize=16)
plt.ylabel("Percentage of People",fontsize=16)
plt.legend(fontsize=16)

# %% [markdown]
# # We FURTHER search beta between 0.5 and 0.55, v between 0.05 and 0.08, with the minima distance being 0.0001

# %%
testbeta=np.linspace(0.5,0.6,1001)
testv=np.linspace(0.05,0.1,501)

# %%
error=np.zeros(501501)
for i in range(1001):
    for j in range(501):
        k=i*501+j
        tests=np.zeros(61)
        testi=np.zeros(61)
        testr=np.zeros(61)
        tests[0]=esusc[0]
        testi[0]=einfe[0]
        testr[0]=ereco[0]
        es=0
        ei=0
        er=0
        for l in range(60):
            tests[l+1]=PCS(testbeta[i],tests[l],testi[l],testv[j],deltaT)
            testi[l+1]=PCI(testbeta[i],tests[l],testi[l],testv[j],deltaT)
            testr[l+1]=PCR(tests[l],testi[l],testr[l],testv[j],deltaT)
            es+=(tests[l+1]-esusc[l+1])**2
            ei+=(testi[l+1]-einfe[l+1])**2
            er+=(testr[l+1]-ereco[l+1])**2
        error[k]=es+ei+er

# %%
print(np.where(error==np.min(error)))
# Out:
# (array([480941], dtype=int64),)

# %%
print(testbeta[959])
print(testv[482])
# Out:
# 0.5959
# 0.09820000000000001

# %%
fitesusc3=np.zeros(61)
fiteinfe3=np.zeros(61)
fitereco3=np.zeros(61)
fitesusc3[0]=esusc[0]
fiteinfe3[0]=einfe[0]
fitereco3[0]=ereco[0]
for i in range(60):
    fitesusc3[i+1]=PCS(0.5959,fitesusc2[i],fiteinfe2[i],0.0982,deltaT)
    fiteinfe3[i+1]=PCI(0.5959,fitesusc2[i],fiteinfe2[i],0.0982,deltaT)
    fitereco3[i+1]=PCR(fitesusc2[i],fiteinfe2[i],fitereco2[i],0.0982,deltaT)
    
plt.figure(figsize=(12,12))
plt.scatter(Te,fitesusc3,linewidth="2",label="Susceptible fitted value",color="Red")
plt.scatter(Te,fiteinfe3,linewidth="2",label="Infected fitted value",color="green")
plt.scatter(Te,fitereco3,linewidth="2",label="Removed fitted value",color="blue")
plt.plot(Te,esusc,linewidth="2",label="Susceptible",color="Red")
plt.plot(Te,einfe,linewidth="2",label="Infected",color="green")
plt.plot(Te,ereco,linewidth="2",label="Removed",color="blue")
plt.title("Ebola data",fontsize=20)
plt.xlabel("Time(Days)",fontsize=16)
plt.ylabel("Percentage of People",fontsize=16)
plt.legend(fontsize=16)
